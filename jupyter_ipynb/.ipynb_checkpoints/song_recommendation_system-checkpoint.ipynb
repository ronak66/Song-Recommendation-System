# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from yellowbrick.cluster import KElbowVisualizer
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# # Data Normalization

# %%
df = pd.read_csv('../Data/final.csv')
print(df.shape)
df.head()
# Out:
# (10449, 20)
#                        id          artist                 name  popularity  \
# 0  2b8fOow8UzyDFAE27YhOZM        Maroon 5             Memories          99
# 1  6WrI0LAC5M1Rw2MnX2ZvEg        Dua Lipa      Don't Start Now          95
# 2  3ZCTVFBt2Brf31RLEnCkWJ   Billie Eilish  everything i wanted          94
# 3  696DnlkuDOXcMAnKlTgXXK  Arizona Zervas              ROXANNE          88
# 4  4VginDwYTP2eaHJzO0QMjG     Post Malone              Circles          68
#
#                                              preview  danceability  energy  \
# 0                                                NaN         0.764   0.320
# 1  https://p.scdn.co/mp3-preview/ed151225213380a4...         0.794   0.793
# 2                                                NaN         0.704   0.225
# 3  https://p.scdn.co/mp3-preview/17c8499c72603f1a...         0.621   0.601
# 4                                                NaN         0.704   0.758
#
#     key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0  11.0    -7.209   1.0       0.0546        0.8370           0.00000
# 1  11.0    -4.521   0.0       0.0842        0.0125           0.00000
# 2   6.0   -14.454   0.0       0.0994        0.9020           0.65700
# 3   6.0    -5.616   0.0       0.1480        0.0522           0.00000
# 4   0.0    -3.537   1.0       0.0402        0.2330           0.00144
#
#    liveness  valence    tempo            type  duration_ms  time_signature  \
# 0    0.0822    0.575   91.019  audio_features     189486.0             4.0
# 1    0.0952    0.677  123.941  audio_features     183290.0             4.0
# 2    0.1060    0.243  120.006  audio_features     245426.0             4.0
# 3    0.4600    0.457  116.735  audio_features     163636.0             5.0
# 4    0.0924    0.534  120.003  audio_features     214907.0             4.0
#
#       label
# 0  toplists
# 1  toplists
# 2  toplists
# 3  toplists
# 4  toplists

# %%
cols = ['artist','danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo','duration_ms','time_signature','label']
non_categorical = ['danceability','energy','loudness','speechiness','acousticness','instrumentalness','liveness','valence','tempo','duration_ms']
categorical = ['artist','key','mode','time_signature','label']

# %ms = MinMaxScaler()
df[non_categorical] = df[non_categorical].apply(lambda x: (x - x.min()) / (x.max() - x.min()))
# df[non_categorical] = mms.fit_transform(df[non_categorical])
df.head()
# Out:
#                        id          artist                 name  popularity  \
# 0  2b8fOow8UzyDFAE27YhOZM        Maroon 5             Memories          99
# 1  6WrI0LAC5M1Rw2MnX2ZvEg        Dua Lipa      Don't Start Now          95
# 2  3ZCTVFBt2Brf31RLEnCkWJ   Billie Eilish  everything i wanted          94
# 3  696DnlkuDOXcMAnKlTgXXK  Arizona Zervas              ROXANNE          88
# 4  4VginDwYTP2eaHJzO0QMjG     Post Malone              Circles          68
#
#                                              preview  danceability  energy  \
# 0                                                NaN      0.782787   0.320
# 1  https://p.scdn.co/mp3-preview/ed151225213380a4...      0.813525   0.793
# 2                                                NaN      0.721311   0.225
# 3  https://p.scdn.co/mp3-preview/17c8499c72603f1a...      0.636270   0.601
# 4                                                NaN      0.721311   0.758
#
#     key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0  11.0  0.867161   1.0     0.060331      0.840361           0.00000
# 1  11.0  0.911314   0.0     0.093039      0.012550           0.00000
# 2   6.0  0.748152   0.0     0.109834      0.905622           0.65700
# 3   6.0  0.893328   0.0     0.163536      0.052410           0.00000
# 4   0.0  0.927478   1.0     0.044420      0.233936           0.00144
#
#    liveness   valence     tempo            type  duration_ms  time_signature  \
# 0  0.082863  0.585540  0.377600  audio_features     0.133347             4.0
# 1  0.095968  0.689409  0.514180  audio_features     0.128744             4.0
# 2  0.106855  0.247454  0.497855  audio_features     0.174910             4.0
# 3  0.463710  0.465377  0.484285  audio_features     0.114141             5.0
# 4  0.093145  0.543788  0.497843  audio_features     0.152235             4.0
#
#       label
# 0  toplists
# 1  toplists
# 2  toplists
# 3  toplists
# 4  toplists

# %% [markdown]
# # Data Visualization

# %%
corr = df[non_categorical].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row0_col1 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row0_col2 {
#             background-color:  #f7b396;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row0_col3 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row0_col4 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row0_col5 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row0_col6 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row0_col7 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row0_col8 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row0_col9 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row1_col0 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row1_col2 {
#             background-color:  #de614d;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row1_col3 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row1_col5 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row1_col6 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row1_col7 {
#             background-color:  #eed0c0;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row1_col8 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row1_col9 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row2_col0 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row2_col1 {
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row2_col3 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row2_col4 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row2_col6 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row2_col7 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row2_col8 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row2_col9 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row3_col0 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row3_col1 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row3_col2 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row3_col4 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row3_col5 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row3_col6 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row3_col7 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row3_col8 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row3_col9 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row4_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row4_col5 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row4_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row4_col7 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row4_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row4_col9 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row5_col0 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row5_col1 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row5_col2 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row5_col3 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row5_col4 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row5_col6 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row5_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row5_col8 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_329d1d16_1ce5_11ea_93cb_10f0057c9f98row5_col9 {
#             background-color:  #7ea1fa;
#             color:  #000000;

# %%
def cluster_plot(new_data):    
    kmeans = KMeans(n_clusters=4, init='k-means++', max_iter=300, n_init=10, random_state=0)
    pred_y = kmeans.fit_predict(new_data)
    t = [30,40,50,60,70,80,90]
    label_color = [t[i] for i in pred_y]
    plt.figure(figsize = (7,7))
    plt.scatter(new_data.iloc[:,0],new_data.iloc[:,1], c=label_color, alpha=0.5,cmap='viridis') 
    plt.show()

def silhouette(new_data):
    kmeans = KMeans(random_state=0)
    visualizer = KElbowVisualizer(kmeans, k=(2,11), metric='silhouette', timings=False)
    visualizer.fit(new_data)    
    visualizer.poof()

# %%
cluster_plot(df[non_categorical])

# %% [markdown]
# # PCA ( Principal Component Analysis)

# %%
pca = PCA(0.95)
data = df.drop_duplicates()
data = pca.fit_transform(data[non_categorical])
cluster_plot(pd.DataFrame(data))
pd.DataFrame(data).head()
# Out:
#           0         1         2         3         4         5         6
# 0  0.256127 -0.521810  0.138744 -0.090820  0.127173 -0.112514  0.063021
# 1 -0.542197  0.000944  0.128033 -0.145677  0.016477 -0.030308 -0.002892
# 2  0.773966  0.020488  0.155532 -0.135814  0.148499 -0.179592 -0.091042
# 3 -0.339391  0.045402 -0.145966  0.077931  0.211139  0.173919 -0.092936
# 4 -0.325794 -0.065218  0.008516 -0.083025 -0.002374 -0.125450  0.046105

# %%
data = pd.DataFrame(data)
silhouette(data)

# %% [markdown]
# #### From the above graph we can determine that the clustering algorithm requires four clusters

# %% [markdown]
# # Model Training

# %%
def train(df_train):
    n = 1
    for _ in range(n):
        # train_df, test_df = train_test_split(df_train)
        km = KMeans(
            n_clusters=4, init='random',
            n_init=10, max_iter=1000, 
            tol=1e-04, random_state=0
        )
        y_km = km.fit(df_train)
        # km.labels_
        # km.predict(test_df)
    return km

def k_mean_distance(center_coordinates, data_coordiantes):
    summ=0
    mag=0
    for i in range(len(center_coordinates)):
        summ+=(center_coordinates[i]-data_coordiantes[i])**2
        mag+=(data_coordiantes[i])**2
    return (summ)*0.5

# %%
km = train(data)
data = pd.DataFrame(data)
# pickle.dump(km, open('KMeans_Clustering', 'wb'))
data['label'] = km.labels_
data['artist'] = df.artist
data['name'] = df.name
data['preview'] = df.preview
data['popularity'] = df.popularity
data['type'] = df.label
data.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.256127 -0.521810  0.138744 -0.090820  0.127173 -0.112514  0.063021
# 1 -0.542197  0.000944  0.128033 -0.145677  0.016477 -0.030308 -0.002892
# 2  0.773966  0.020488  0.155532 -0.135814  0.148499 -0.179592 -0.091042
# 3 -0.339391  0.045402 -0.145966  0.077931  0.211139  0.173919 -0.092936
# 4 -0.325794 -0.065218  0.008516 -0.083025 -0.002374 -0.125450  0.046105
#
#    label          artist                 name  \
# 0      1        Maroon 5             Memories
# 1      3        Dua Lipa      Don't Start Now
# 2      2   Billie Eilish  everything i wanted
# 3      3  Arizona Zervas              ROXANNE
# 4      3     Post Malone              Circles
#
#                                              preview  popularity      type
# 0                                                NaN          99  toplists
# 1  https://p.scdn.co/mp3-preview/ed151225213380a4...          95  toplists
# 2                                                NaN          94  toplists
# 3  https://p.scdn.co/mp3-preview/17c8499c72603f1a...          88  toplists
# 4                                                NaN          68  toplists

# %% [markdown]
# # Generating Outcome

# %%
def song_recommendation(song,data):
    arr = []
    dummy_df = data.loc[data['label']==song.label.values[0]]
    print(len(dummy_df.values))
    for i in range(len(dummy_df.values)):
        if(i>51): break
        dist = k_mean_distance(dummy_df.values[i][0:7],song.values[0][0:7])
        arr.append((
            dummy_df.values[i][11]/(dist+0.00000001)**2,
            dist,
            dummy_df.values[i][11],
            dummy_df.values[i][8],
            dummy_df.values[i][9],
            dummy_df.values[i][10],
            dummy_df.values[i][12]
        ))
    arr.sort()
    return arr

def song_print(song):
    print('='*200)
    print('Artist:  ', song.artist.values[0])
    print('Song Name:   ', song.name.values[0])
    print('Type:   ', song['type'].values[0])
    print('Preview link:   ', song.preview.values[0])
    print('='*200)

# %%
song = data.loc[[2980]]
ans = song_recommendation(song,data)
song_print(song)
j=1
for i in ans[::-1]:
    print('Number:  ', j)
    print('Popularity/distance:  ',i[0])
    print('Artist:  ', i[3])
    print('Song Name:   ', i[4])
    print('Type:   ', i[6])
    print('Preview link:   ', i[5])
    print('-'*100)
    j+=1
# Out:
# 2448
# ========================================================================================================================================================================================================
# Artist:   Cigarettes After Sex
# Song Name:    Falling In Love
# Type:    decades
# Preview link:    https://p.scdn.co/mp3-preview/b99534447943c33a206c56cffb0b63f818aa7e1e?cid=99f699c35c2d4667917d680d9134d27e
# ========================================================================================================================================================================================================
# Number:   1
# Popularity/distance:   137854.790551392
# Artist:   Lewis Capaldi
# Song Name:    Someone You Loved
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   2
# Popularity/distance:   100415.84526848306
# Artist:   Jhené Aiko
# Song Name:    Triggered - Remix
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   3
# Popularity/distance:   32794.37444903737
# Artist:   Bruno Major
# Song Name:    Tapestry
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/d56ef54b6fbcdfbfd361805c586520df4442dda2?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   4
# Popularity/distance:   26451.812193855752
# Artist:   SHAED
# Song Name:    Trampoline (with ZAYN)
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   5
# Popularity/distance:   23722.205695191715
# Artist:   Selena Gomez
# Song Name:    Lose You To Love Me
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   6
# Popularity/distance:   20127.793216537902
# Artist:   Dean Lewis
# Song Name:    Be Alright
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   7
# Popularity/distance:   19764.784269152693
# Artist:   PJ Morton
# Song Name:    BUILT FOR LOVE (feat. Jazmine Sullivan)
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/9d8e8590529f880f9f8afb365885975461d48961?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   8
# Popularity/distance:   17492.290040584026
# Artist:   Summer Walker
# Song Name:    Playing Games (with Bryson Tiller) - Extended Version
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   9
# Popularity/distance:   17260.64812571815
# Artist:   Nina Nesbitt
# Song Name:    Still Waiting to Start
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/0a8d12a85b4d96f42dce5b145964750ea6df4698?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   10
# Popularity/distance:   14689.90257049351
# Artist:   Kelsea Ballerini
# Song Name:    homecoming queen?
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/b48e810e0950f16e1e8352de28f5f746caf8b0e0?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   11
# Popularity/distance:   13162.008431941162
# Artist:   Jhené Aiko
# Song Name:    None Of Your Concern
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   12
# Popularity/distance:   12551.735888780175
# Artist:   Noah Cyrus
# Song Name:    July
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/b772266fa0e6a75c3d73a816f86098c0a96de110?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   13
# Popularity/distance:   12231.165089434948
# Artist:   Tank
# Song Name:    Somebody Else (feat. JoJo)
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/d517b7dae776a2588ff01280c56fb347d550531f?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   14
# Popularity/distance:   12055.236383278496
# Artist:   Pink Sweat$
# Song Name:    Honesty - Remix
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/0a88ebc7b96b016cd13e35dbe8df6adb6bff33fb?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   15
# Popularity/distance:   11654.83233078476
# Artist:   Lewis Capaldi
# Song Name:    Before You Go
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   16
# Popularity/distance:   11608.75066091768
# Artist:   Old Dominion
# Song Name:    One Man Band
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   17
# Popularity/distance:   9921.075074068242
# Artist:   Doja Cat
# Song Name:    Candy
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/b8ec099e8d5570410ec45e21af21147ff5e84dcf?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   18
# Popularity/distance:   9566.254783997458
# Artist:   Maroon 5
# Song Name:    Memories
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   19
# Popularity/distance:   9109.038657615998
# Artist:   JP Saxe
# Song Name:    If The World Was Ending (feat. Julia Michaels)
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/018d975f965ed16e92e601c53afa1c7e7ce9ab27?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   20
# Popularity/distance:   9018.394708400832
# Artist:   HAIM
# Song Name:    Hallelujah
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   21
# Popularity/distance:   8046.490977763269
# Artist:   Morgan Wallen
# Song Name:    Chasin' You
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/315a23892d7b637a14a15b45d411f8d28f604059?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   22
# Popularity/distance:   7145.291710312965
# Artist:   Daniel Caesar
# Song Name:    CYANIDE
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/f46092682053fdc38645a6e3379e25aed6b970aa?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   23
# Popularity/distance:   6867.90995750785
# Artist:   Khole
# Song Name:    U Suck
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/abfb6fc446e43566632d86526d65235761cf1c97?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   24
# Popularity/distance:   6456.43546372423
# Artist:   TINI
# Song Name:    Oye
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   25
# Popularity/distance:   6114.306469256123
# Artist:   Thomas Rhett
# Song Name:    Remember You Young
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   26
# Popularity/distance:   6079.995971421315
# Artist:   Florida Georgia Line
# Song Name:    Blessings
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   27
# Popularity/distance:   5952.69481238511
# Artist:   Bad Bunny
# Song Name:    Callaita
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/23c0b25cf824c1bfd7a814fe7cd1264c31a5a9dc?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   28
# Popularity/distance:   5664.904136619552
# Artist:   benny blanco
# Song Name:    Eastside (with Halsey & Khalid)
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   29
# Popularity/distance:   5611.002117777113
# Artist:   Hannah Diamond
# Song Name:    The Ending
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/a2eaa2e9880a58bac64c11b60eacb11a7c0ea258?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   30
# Popularity/distance:   5452.340977431736
# Artist:   Kane Brown
# Song Name:    Homesick
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   31
# Popularity/distance:   5443.471641639808
# Artist:   The Japanese House
# Song Name:    Chewing Cotton Wool
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/e9ed8200f020dfe1ae6f6c25d66a237d4ffdc744?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   32
# Popularity/distance:   4798.825695758026
# Artist:   Drake
# Song Name:    Behind Barz - Bonus
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/73e9e47faa119ff50413dc7068362cbc1aef6c65?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   33
# Popularity/distance:   4769.286918225704
# Artist:   Labrinth
# Song Name:    Oblivion (feat. Sia)
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/83a1957b422472f34db270af27d68b21b97a58f2?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   34
# Popularity/distance:   4542.179861443458
# Artist:   Tatak Pinoy All-Stars
# Song Name:    A Perfect Christmas - Recorded at OnQ Studios, Manila
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/92b85eb113d2b906f2e6f102b94223b0e0968dbb?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   35
# Popularity/distance:   4267.886020982632
# Artist:   Taylor Swift
# Song Name:    Lover (Remix) [feat. Shawn Mendes]
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   36
# Popularity/distance:   2826.1448994147945
# Artist:   Mustard
# Song Name:    Ballin' (with Roddy Ricch)
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   37
# Popularity/distance:   2633.5823473260793
# Artist:   Teyana Taylor
# Song Name:    Morning
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   38
# Popularity/distance:   2399.4521874244933
# Artist:   SMTOWN
# Song Name:    This is Your Day (for every child, UNICEF)
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/9be7a6e9e97dc29bc029541acd26b45832456d99?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   39
# Popularity/distance:   2297.9061338738693
# Artist:   Tones and I
# Song Name:    Dance Monkey
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   40
# Popularity/distance:   2279.9749197742003
# Artist:   Tank
# Song Name:    I Don't Think You're Ready
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   41
# Popularity/distance:   2120.968045259419
# Artist:   Elderbrook
# Song Name:    Something About You (with Rudimental)
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/75705ae7c893e0c6af8a3c27694aa23637286f77?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   42
# Popularity/distance:   2120.5605539165213
# Artist:   RUFUS
# Song Name:    atlantis
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/68464f6680387536d10ff0c76a0696be110272cb?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   43
# Popularity/distance:   1277.324887213354
# Artist:   Grace VanderWaal
# Song Name:    Poser
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/16993ee7a2a64f3a63076103db2d8031c967c320?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   44
# Popularity/distance:   1069.3456772900352
# Artist:   Sam Hunt
# Song Name:    Sinning With You
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   45
# Popularity/distance:   842.3353736397811
# Artist:   Natti Natasha
# Song Name:    La Mejor Versión de Mi - Remix
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/d32ea1dc5c840ea3ebb4ddb5e99b936abc8d1b55?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   46
# Popularity/distance:   141.72741480553566
# Artist:   Ghaniyya ghazi
# Song Name:    Can't Live
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/55fbabc2134e2b96630b2b9dbf2aa0889fc50e46?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   47
# Popularity/distance:   140.74341289327188
# Artist:   Speax
# Song Name:    GSP
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/fd964ba7b49f5840db3a49141c9d42dfd92fa5b5?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   48
# Popularity/distance:   97.69236866114616
# Artist:   Airinna Namara
# Song Name:    Don't Let Me Go While I'm Here
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/5fb8b52cdabc9f81285b1cc68b8ecf919dffaa69?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   49
# Popularity/distance:   89.728968281898
# Artist:   dadeft
# Song Name:    Betty Ross
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/828c4d87427d20401f3b7e3fe49cb71148ebfdfe?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   50
# Popularity/distance:   0.0
# Artist:   Various Artists
# Song Name:    today's best dance
# Type:    toplists
# Preview link:    nan
# ----------------------------------------------------------------------------------------------------
# Number:   51
# Popularity/distance:   0.0
# Artist:   PARTYNEXTDOOR
# Song Name:    Loyal (feat. Drake)
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/9cd34e105748351edc7aa6deb0e05b3d6ffd4c7f?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------
# Number:   52
# Popularity/distance:   0.0
# Artist:   SUNGMIN
# Song Name:    Orgel
# Type:    toplists
# Preview link:    https://p.scdn.co/mp3-preview/7f407a752b82944b957115417805701e1f9658b5?cid=99f699c35c2d4667917d680d9134d27e
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Model Evaluation

# %%
data_eval = data.iloc[:,0:7]

# %%
from yellowbrick.cluster import SilhouetteVisualizer
kmeans = KMeans(4, random_state=42)
visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick')
plt.figure(figsize = (7,7))
visualizer.fit(data_eval)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
from yellowbrick.cluster import InterclusterDistance

# Generate synthetic dataset with 12 random clusters
# Instantiate the clustering model and visualizer
model = KMeans(4, random_state=42)
visualizer = InterclusterDistance(model)
plt.figure(figsize = (10,10))
visualizer.fit(data_eval)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure
